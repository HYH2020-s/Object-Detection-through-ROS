# %%
import sys
sys.path.remove('/opt/ros/kinetic/lib/python2.7/dist-packages')

# %%
import cv2
from cv2 import VideoWriter,VideoWriter_fourcc,imread,resize
import os
img_root="/home/reg1s/Postgraduate/TeamProject/Data/14"
#Edit each frame's appearing time!
fps=33
fourcc=VideoWriter_fourcc(*"MJPG")
videoWriter=cv2.VideoWriter("/home/reg1s/Postgraduate/TeamProject/Data/video/14.avi",fourcc,fps,(1280,720))

im_names=os.listdir(img_root)

# %%
for im_name in range(2,len(im_names)):
    frame=cv2.imread(img_root+'/frame'+str(im_name).zfill(4)+'.jpg')
    print(img_root+'/frame'+str(im_name).zfill(4)+'.jpg')
    videoWriter.write(frame)
# Out:
# /home/reg1s/Postgraduate/TeamProject/Data/14/frame0002.jpg
# /home/reg1s/Postgraduate/TeamProject/Data/14/frame0003.jpg
# /home/reg1s/Postgraduate/TeamProject/Data/14/frame0004.jpg
# /home/reg1s/Postgraduate/TeamProject/Data/14/frame0005.jpg
# /home/reg1s/Postgraduate/TeamProject/Data/14/frame0006.jpg
# /home/reg1s/Postgraduate/TeamProject/Data/14/frame0007.jpg
# /home/reg1s/Postgraduate/TeamProject/Data/14/frame0008.jpg
# /home/reg1s/Postgraduate/TeamProject/Data/14/frame0009.jpg
# /home/reg1s/Postgraduate/TeamProject/Data/14/frame0010.jpg
# /home/reg1s/Postgraduate/TeamProject/Data/14/frame0011.jpg
# /home/reg1s/Postgraduate/TeamProject/Data/14/frame0012.jpg
# /home/reg1s/Postgraduate/TeamProject/Data/14/frame0013.jpg
# /home/reg1s/Postgraduate/TeamProject/Data/14/frame0014.jpg
# /home/reg1s/Postgraduate/TeamProject/Data/14/frame0015.jpg
# /home/reg1s/Postgraduate/TeamProject/Data/14/frame0016.jpg
# /home/reg1s/Postgraduate/TeamProject/Data/14/frame0017.jpg
# ...
